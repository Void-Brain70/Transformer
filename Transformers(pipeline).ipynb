# %% [markdown]
# <a href="https://colab.research.google.com/github/Void-Brain70/Transformer/blob/main/Transformers(pipeline).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 29.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 50.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 44.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import transformers

# %%
# !pip install transformers[sentencepiece]
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 27.8 MB/s
# ...

# %% [markdown]
# **pipeline() Function**

# %% [markdown]
# We will try the pipeline API on is sentiment analysis.It classify texts as positive or negative

# %% [markdown]
# **Available pipeline are**

# %% [markdown]
# 1.feature-extraction (get the vector representation of a text)
# 2.fill-mask
# 3.ner (named entity recognition)
# 4.question-answering
# 5.sentiment-analysis
# 6.summarization
# 7.text-generation
# 8.translation
# 9.zero-shot-classification

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9598048329353333}]

# %%
# sentiment-analysis
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", 
     "I hate this so much!"]
)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# [{'label': 'POSITIVE', 'score': 0.9598048329353333},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier(
    ["I love CSE", 
     "I hate CSE"]
)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# [{'label': 'POSITIVE', 'score': 0.9998409748077393},
#  {'label': 'NEGATIVE', 'score': 0.9991482496261597}]

# %%
# the zero-shot-classification pipeline is very powerful
# zero-shot-classification
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# {'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445989489555359, 0.11197411268949509, 0.04342697188258171],
#  'sequence': 'This is a course about the Transformers library'}

# %%
# zero-shot-classification
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "I am anik chandra,i read cse in university of asia pacific",
    candidate_labels=["anik", "UAP", "CSE"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# {'labels': ['anik', 'CSE', 'UAP'],
#  'scores': [0.8483522534370422, 0.11760438233613968, 0.03404337912797928],
#  'sequence': 'I am anik chandra,i read cse in university of asia pacific'}

# %%
#Text generation
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "In this course, we will teach you how to make your own tools. Let's think for a moment about their capabilities. Imagine you have a game called 'Lazyjack' for Windows. In it, you have your own unique, very simple"}]

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("Computer Science and Engineering")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Computer Science and Engineering Faculty, St. Mary's College.\n\nUniversity Associate Professor\n\nRandy K. Sabin, Stanford University School of Medicine.\n\nProfessor in Surgical Dentistry. M.D. in Gerontological Dent"}]

# %%
# Model-> distilgpt2
# Pipeline-> Text-Generation 
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to do so. All instructors should share this same lesson and create an educational tool for learning how to deal'},
#  {'generated_text': 'In this course, we will teach you how to find a solid library or an HTML web framework that can be used in your real life business!\n'}]

# %%
# Model-> distilgpt2
# Pipeline-> Text-Generation
# "num_return_sequences" and the total length of the output text with the argument max_length 
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "Bangladesh is a beautiful country",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Bangladesh is a beautiful country with a number of amazing rivers that rise from the sea. The mountains are rich with natural springs—it is a'},
#  {'generated_text': 'Bangladesh is a beautiful country where immigrants in many parts of the world are living their full lives in the hope that they will be able to play'}]
